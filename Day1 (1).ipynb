# %%
print("Hello World")
'''
s bnc sbn snb s
scbsjsv
hjcvshvbhjv
hjvhjsvhjs
'''
#fghfvjgvhjgkghjvhjvghcfjcbahjcvsjc jh
name = "  Tanaya "
last_name='Mote'
print(name)
print(type(name))
print (last_name)
print(type(last_name))

age=12
abc = True
percentage= 78.90
print(age)
print(type(age))
print(abc)
print(type(abc))
print(percentage)
print(type(percentage))
print ("My name is",name ,"and last name is ", last_name, "and age is ", age)
# Out:
# Hello World
#   Tanaya
# <class 'str'>
# Mote
# <class 'str'>
# 12
# <class 'int'>
# True
# <class 'bool'>
# 78.9
# <class 'float'>
# My name is   Tanaya  and last name is  Mote and age is  12

# %%
num = int(input ("Enter your num: "))
print (num)
print (type(num))
# Out:
# Enter your num: 21
# 21
# <class 'int'>

# %%
# Arithmetic Operators

#Addition
a = 5
b = 7
print (a+b)
print (a-b)
print (a*b)
print (a/b)
print (a**b)
print (a%b)
print (a//b)
# Out:
# 12
# -2
# 35
# 0.7142857142857143
# 78125
# 5
# 0

# %%
# Comparision Operator

a = 6
b = 6

print (a>b)
print (a<b)
print (a==b)
print (a<=b)
print (a>=b)
# Out:
# False
# False
# True
# True
# True

# %%
age = 14
print(age > 18 or age < 65)
# Out:
# True

# %%
# Assignment Operater

a = 5
print (a)
a += 10
#a= a+ 10

print (a)
a -= 4
print (a)
#a= a-4

a *= 5
#a= a*5
print (a)

a /= 5
# a = a/5
print (a)
# Out:
# 5
# 15
# 11
# 55
# 11.0

# %%
text = "Python"
print("P" in text)
# Out:
# True

# %%
a = 10
b = a
print(a is b)
print (a == b)
print (a is not b)
print (a != b)
print (b)
print (type(a))
print (type(b))
# Out:
# True
# True
# False
# False
# 10
# <class 'int'>
# <class 'int'>

# %%
# Conditional Statements
# if , elif , else

a = 11
b = 10

if (a < b):
 print ("Hello")

elif (a > b):
  print ("Okay")

elif (a == b):
  print ("World")
else:
  print ("Bye")


if(a != b ):
  print ("Kartik")
# Out:
# Okay
# Kartik

# %%
x=int(input("enter value of x:"))
y=(2*x+3)
print(y)
# Out:
# enter value of x:23
# 49

# %%
temp=int(input("enter temp:"))
if(temp>30):
  print("hot")
else:
  print("Normal")
# Out:
# enter temp:67
# hot

# %%
for i in range(10):
    if i == 3:
      break
      #continue
      #print(i)
    print(i)
# Out:
# 0
# 1
# 2

# %%
a = [1,2,3,4,5,6]
for i in a:
  print (i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
text = "Python is  a programming language"

print(text[0:3])   # Pyt
print(text[2:])    # thon
print(text[:4])    # Pyth
print(text[-1])    # n (last character)
print(text[::-1])  # Reverse string
# Out:
# Pyt
# thon is  a programming language
# Pyth
# e
# egaugnal gnimmargorp a  si nohtyP

# %%
text = "Python is  a programming language"
print(text.upper())  # PYTHON
print(text.lower())  # python
# Out:
# PYTHON IS  A PROGRAMMING LANGUAGE
# python is  a programming language

# %%
#replace
text = "Hello World"
print(text.replace("World","Python"))
# Out:
# Hello Python

# %%
#split
text = "Python is  a programming language"
print(text.split("a"))
# Out:
# ['Python is  ', ' progr', 'mming l', 'ngu', 'ge']

# %%
text = "Shubham   "
print (len(text))
# Out:
# 10

# %%
#user based non parameters function
def greeting ():
  a=10
  b=20
  print(a+b)
  print ("Hello World")

greeting ()
# Out:
# 30
# Hello World

# %%
#user based  parameters function
def details (First_Name):
  print (f"My name is {First_Name}")
  print ("my Name is ", First_Name)

details("SHubham")
#details()
# Out:
# My name is SHubham
# my Name is  SHubham

# %%
#functions with multiple value and return
 #       5, 6
def add (x,y):
  print("The addition of 2 no is :", x+y)
  return x+y

result = add (5,6)
print (result)
add(10,30)
# Out:
# The addition of 2 no is : 11
# 11
# The addition of 2 no is : 40
# 40

# %%
def greet(name="World"):
    print("Hello", name)

greet()
# Out:
# Hello World

# %%
#Keyword Arguments Function
def info(name, age, last_name):
    print(name, age,last_name)

info(age=21, name="Kartik" , last_name="Dhangar")
info(age=34, name="Aditya" , last_name="Patil")
# Out:
# Kartik 21 Dhangar
# Aditya 34 Patil

# %%
#kwargs functions
def display(**details):
    print(details)

display(name="Kartik", age=21,address="Mumbai")
display(name="Kartik", age="Kartik",address="Mumbai")
# Out:
# {'name': 'Kartik', 'age': 21, 'address': 'Mumbai'}
# {'name': 'Kartik', 'age': 'Kartik', 'address': 'Mumbai'}

# %%
#lamba function
add = lambda a, b: a + b
print(add(2, 3))
# Out:
# 5

# %%
# ==============================
# 📌 Q3. Average of Features
# ==============================

nums = []

for i in range(5):
    val = float(input("ENter No"))
    nums.append(val)

avg = sum(nums) / len(nums)
print("Average:", avg)
# Out:
# ENter No32
# ENter No21
# ENter No45
# ENter No2
# ENter No4
# Average: 20.8

# %%
class Person:

   Name='Shubham'
   L_Name='Dhangar'
   Roll_No=1001
   Barnch="CS"

shubham = Person()
aditya = Person()



print(shubham.Name, shubham.L_Name, shubham.Roll_No, shubham.Barnch)
# Out:
# Shubham Dhangar 1001 CS

# %%
class Dog:
  species = "Canine" # Class Attribute

  def __init__(self, name, age):
    self.name = name # Instance Attribute
    self.age = age # Instance Attribute

#Creating an object of a Dog Class
dog1 = Dog("Buddy", 3)
dog2= Dog("Miky", 7)

print (dog1.name)
print (dog1.age)
print (dog1.species)
# Out:
# Buddy
# 3
# Canine

# %%
class Dog:
    species = "Canine"  # Class attribute

    def __init__(self, name, age):
        self.name = name
        self.age = age

    def animal_name(self, dog, cat):
        self.dog = dog
        self.cat = cat
        print("Dog name:", self.dog)
        print("Cat name:", self.cat)

    def location(self, state, country):
        self.state = state
        self.country = country
        print("State:", self.state)
        print("Country:", self.country)



# Taking input from user
name = input("Enter dog object name: ")
age = int(input("Enter age: "))

dog_value = input("Enter dog name: ")
cat_value = input("Enter cat name: ")

# Creating object
d = Dog(name, age)
print (d.name)
print (d.age)
print (d.species)
# Calling function with user input
d.animal_name(dog_value, cat_value)

d.location("Maharashtra", "India")
# Out:
# Enter dog object name: a
# Enter age: 3
# Enter dog name:
# Enter cat name: f
# a
# 3
# Canine
# Dog name:
# Cat name: f
# State: Maharashtra
# Country: India
